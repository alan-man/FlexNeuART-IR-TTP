# %% [markdown]
# # Experimentation: Tuning BM25 & Model 1

# %% [markdown]
# Experiments are described using simple eperimental descriptors, which we will store in the directory `collections/wikipedia_dpr_nq_sample/exper_desc`. The provided tar-ball with data has some key experimental descriptors. However, it does not have descriptors to tune BM25 and the fusion of BM25 with other models.

# %% [markdown]
# ### Two things to do before we start:
# 1. Point environment variable `COLLECT_ROOT` to the collection root.
# 2. Change directory to the location of installed scripts/binaries

# %%
import os
COLLECT_ROOT = os.path.abspath("collections")
os.makedirs(COLLECT_ROOT, exist_ok=True)
# %env COLLECT_ROOT={COLLECT_ROOT}
print(COLLECT_ROOT)
# Out:
# env: COLLECT_ROOT=/tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections
# /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections

# %%
# %cd ./flexneuart_scripts/
# Out:
# /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/flexneuart_scripts

# %% [markdown]
#  ... and create a directory to store **experiment descriptors**:

# %%
# !mkdir -p $COLLECT_ROOT/wikipedia_dpr_nq_sample/exper_desc

# %% [markdown]
# ## Tuning BM25
# A tuning procedure simply executes a number of descriptor files
# with various BM25 parameters. To create descriptors one runs:

# %%
# !./gen_exper_desc/gen_bm25_tune_json_desc.py \
  --index_field_name text \
  --query_field_name text \
  --outdir $COLLECT_ROOT/wikipedia_dpr_nq_sample/exper_desc/ \
  --exper_subdir tuning \
  --rel_desc_path exper_desc
# Out:
# Namespace(outdir='/tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/exper_desc/', rel_desc_path='exper_desc', exper_subdir='tuning', index_field_name='text', query_field_name='text', cand_prov_uri=None, cand_prov_add_conf=None, cand_prov_qty=None)

# %% [markdown]
# BM25 experiments need a dummy one-feature model, which can be created like this:

# %%
# !mkdir -p $COLLECT_ROOT/wikipedia_dpr_nq_sample/exper_desc/models

# %%
# !cp $COLLECT_ROOT/wikipedia_dpr_nq_sample/exper_desc.best/models/one_feat.model  \
    $COLLECT_ROOT/wikipedia_dpr_nq_sample/exper_desc/models

# %% [markdown]
# The main experimental descriptor is going to be stored in  `collections/wikipedia_dpr_nq_sample/exper_desc/bm25tune.json`,
# whereas auxiliary descriptors are stored in `collections/wikipedia_dpr_nq_sample/exper_desc/bm25tune/`
#
# Now we can run tuning experiments where we train on `train` and test on `dev1`:

# %%
# !./exper/run_experiments.sh \
  wikipedia_dpr_nq_sample \
  exper_desc/bm25tune_text_text.json \
  -test_part dev
# Out:
# Using collection root: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections
# The number of CPU cores:      16
# The number of || experiments: 1
# The number of threads:        16
# ================================================================================
# Experiment descriptor file:                                 /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/exper_desc/bm25tune_text_text.json
# Default test set:                                           dev
# Number of parallel experiments:                             1
# Number of threads in feature extractors/query applications: 16
# ================================================================================
# Parsed experiment parameters:
# experSubdir:tuning/bm25tune_text_text/bm25tune_k1=0.4_b=0.3
# extrTypeFinal:exper_desc/bm25tune_text_text/bm25tune_k1=0.4_b=0.3.json
# testOnly:1
# modelFinal:exper_desc/models/one_feat.model
# ========================================
# Started a process 1062833, working dir: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/bm25tune_text_text/bm25tune_k1=0.4_b=0.3
# Process log file: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/bm25tune_text_text/bm25tune_k1=0.4_b=0.3/exper.log
# Waiting for 1 child processes
# Process with pid=1062833 finished successfully.
# Parsed experiment parameters:
# experSubdir:tuning/bm25tune_text_text/bm25tune_k1=0.6_b=0.3
# extrTypeFinal:exper_desc/bm25tune_text_text/bm25tune_k1=0.6_b=0.3.json
# testOnly:1
# modelFinal:exper_desc/models/one_feat.model
# ========================================
# Started a process 1063495, working dir: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/bm25tune_text_text/bm25tune_k1=0.6_b=0.3
# Process log file: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/bm25tune_text_text/bm25tune_k1=0.6_b=0.3/exper.log
# Waiting for 1 child processes
# Process with pid=1063495 finished successfully.
# Parsed experiment parameters:
# experSubdir:tuning/bm25tune_text_text/bm25tune_k1=0.8_b=0.3
# extrTypeFinal:exper_desc/bm25tune_text_text/bm25tune_k1=0.8_b=0.3.json
# testOnly:1
# modelFinal:exper_desc/models/one_feat.model
# ========================================
# Started a process 1064066, working dir: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/bm25tune_text_text/bm25tune_k1=0.8_b=0.3
# Process log file: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/bm25tune_text_text/bm25tune_k1=0.8_b=0.3/exper.log
# Waiting for 1 child processes
# Process with pid=1064066 finished successfully.
# Parsed experiment parameters:
# experSubdir:tuning/bm25tune_text_text/bm25tune_k1=1_b=0.3
# extrTypeFinal:exper_desc/bm25tune_text_text/bm25tune_k1=1_b=0.3.json
# testOnly:1
# modelFinal:exper_desc/models/one_feat.model
# ========================================
# Started a process 1064590, working dir: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/bm25tune_text_text/bm25tune_k1=1_b=0.3
# Process log file: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/bm25tune_text_text/bm25tune_k1=1_b=0.3/exper.log
# Waiting for 1 child processes
# Process with pid=1064590 finished successfully.
# Parsed experiment parameters:
# experSubdir:tuning/bm25tune_text_text/bm25tune_k1=1.2_b=0.3
# extrTypeFinal:exper_desc/bm25tune_text_text/bm25tune_k1=1.2_b=0.3.json
# testOnly:1
# modelFinal:exper_desc/models/one_feat.model
# ========================================
# Started a process 1065122, working dir: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/bm25tune_text_text/bm25tune_k1=1.2_b=0.3
# Process log file: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/bm25tune_text_text/bm25tune_k1=1.2_b=0.3/exper.log
# Waiting for 1 child processes
# Process with pid=1065122 finished successfully.
# Parsed experiment parameters:
# experSubdir:tuning/bm25tune_text_text/bm25tune_k1=1.4_b=0.3
# extrTypeFinal:exper_desc/bm25tune_text_text/bm25tune_k1=1.4_b=0.3.json
# testOnly:1
# modelFinal:exper_desc/models/one_feat.model
# ========================================
# Started a process 1065667, working dir: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/bm25tune_text_text/bm25tune_k1=1.4_b=0.3
# Process log file: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/bm25tune_text_text/bm25tune_k1=1.4_b=0.3/exper.log
# Waiting for 1 child processes
# Process with pid=1065667 finished successfully.
# Parsed experiment parameters:
# experSubdir:tuning/bm25tune_text_text/bm25tune_k1=1.6_b=0.3
# extrTypeFinal:exper_desc/bm25tune_text_text/bm25tune_k1=1.6_b=0.3.json
# testOnly:1
# modelFinal:exper_desc/models/one_feat.model
# ========================================
# Started a process 1066199, working dir: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/bm25tune_text_text/bm25tune_k1=1.6_b=0.3
# Process log file: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/bm25tune_text_text/bm25tune_k1=1.6_b=0.3/exper.log
# Waiting for 1 child processes
# Process with pid=1066199 finished successfully.
# Parsed experiment parameters:
# experSubdir:tuning/bm25tune_text_text/bm25tune_k1=0.4_b=0.4
# extrTypeFinal:exper_desc/bm25tune_text_text/bm25tune_k1=0.4_b=0.4.json
# testOnly:1
# modelFinal:exper_desc/models/one_feat.model
# ========================================
# Started a process 1066725, working dir: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/bm25tune_text_text/bm25tune_k1=0.4_b=0.4
# Process log file: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/bm25tune_text_text/bm25tune_k1=0.4_b=0.4/exper.log
# Waiting for 1 child processes
# Process with pid=1066725 finished successfully.
# Parsed experiment parameters:
# experSubdir:tuning/bm25tune_text_text/bm25tune_k1=0.6_b=0.4
# extrTypeFinal:exper_desc/bm25tune_text_text/bm25tune_k1=0.6_b=0.4.json
# testOnly:1
# modelFinal:exper_desc/models/one_feat.model
# ========================================
# Started a process 1067278, working dir: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/bm25tune_text_text/bm25tune_k1=0.6_b=0.4
# Process log file: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/bm25tune_text_text/bm25tune_k1=0.6_b=0.4/exper.log
# Waiting for 1 child processes
# Process with pid=1067278 finished successfully.
# Parsed experiment parameters:
# experSubdir:tuning/bm25tune_text_text/bm25tune_k1=0.8_b=0.4
# extrTypeFinal:exper_desc/bm25tune_text_text/bm25tune_k1=0.8_b=0.4.json
# testOnly:1
# modelFinal:exper_desc/models/one_feat.model
# ========================================
# Started a process 1067831, working dir: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/bm25tune_text_text/bm25tune_k1=0.8_b=0.4
# Process log file: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/bm25tune_text_text/bm25tune_k1=0.8_b=0.4/exper.log
# Waiting for 1 child processes
# Process with pid=1067831 finished successfully.
# Parsed experiment parameters:
# experSubdir:tuning/bm25tune_text_text/bm25tune_k1=1_b=0.4
# extrTypeFinal:exper_desc/bm25tune_text_text/bm25tune_k1=1_b=0.4.json
# testOnly:1
# modelFinal:exper_desc/models/one_feat.model
# ========================================
# Started a process 1068385, working dir: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/bm25tune_text_text/bm25tune_k1=1_b=0.4
# Process log file: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/bm25tune_text_text/bm25tune_k1=1_b=0.4/exper.log
# Waiting for 1 child processes
# Process with pid=1068385 finished successfully.
# Parsed experiment parameters:
# experSubdir:tuning/bm25tune_text_text/bm25tune_k1=1.2_b=0.4
# extrTypeFinal:exper_desc/bm25tune_text_text/bm25tune_k1=1.2_b=0.4.json
# testOnly:1
# modelFinal:exper_desc/models/one_feat.model
# ========================================
# Started a process 1068897, working dir: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/bm25tune_text_text/bm25tune_k1=1.2_b=0.4
# Process log file: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/bm25tune_text_text/bm25tune_k1=1.2_b=0.4/exper.log
# Waiting for 1 child processes
# Process with pid=1068897 finished successfully.
# Parsed experiment parameters:
# experSubdir:tuning/bm25tune_text_text/bm25tune_k1=1.4_b=0.4
# extrTypeFinal:exper_desc/bm25tune_text_text/bm25tune_k1=1.4_b=0.4.json
# testOnly:1
# modelFinal:exper_desc/models/one_feat.model
# ========================================
# Started a process 1069433, working dir: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/bm25tune_text_text/bm25tune_k1=1.4_b=0.4
# Process log file: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/bm25tune_text_text/bm25tune_k1=1.4_b=0.4/exper.log
# Waiting for 1 child processes
# Process with pid=1069433 finished successfully.
# Parsed experiment parameters:
# experSubdir:tuning/bm25tune_text_text/bm25tune_k1=1.6_b=0.4
# extrTypeFinal:exper_desc/bm25tune_text_text/bm25tune_k1=1.6_b=0.4.json
# testOnly:1
# modelFinal:exper_desc/models/one_feat.model
# ========================================
# Started a process 1069958, working dir: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/bm25tune_text_text/bm25tune_k1=1.6_b=0.4
# Process log file: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/bm25tune_text_text/bm25tune_k1=1.6_b=0.4/exper.log
# Waiting for 1 child processes
# Process with pid=1069958 finished successfully.
# Parsed experiment parameters:
# experSubdir:tuning/bm25tune_text_text/bm25tune_k1=0.4_b=0.5
# extrTypeFinal:exper_desc/bm25tune_text_text/bm25tune_k1=0.4_b=0.5.json
# testOnly:1
# modelFinal:exper_desc/models/one_feat.model
# ========================================
# Started a process 1070474, working dir: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/bm25tune_text_text/bm25tune_k1=0.4_b=0.5
# Process log file: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/bm25tune_text_text/bm25tune_k1=0.4_b=0.5/exper.log
# Waiting for 1 child processes
# Process with pid=1070474 finished successfully.
# Parsed experiment parameters:
# experSubdir:tuning/bm25tune_text_text/bm25tune_k1=0.6_b=0.5
# extrTypeFinal:exper_desc/bm25tune_text_text/bm25tune_k1=0.6_b=0.5.json
# testOnly:1
# modelFinal:exper_desc/models/one_feat.model
# ========================================
# Started a process 1070989, working dir: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/bm25tune_text_text/bm25tune_k1=0.6_b=0.5
# Process log file: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/bm25tune_text_text/bm25tune_k1=0.6_b=0.5/exper.log
# Waiting for 1 child processes
# Process with pid=1070989 finished successfully.
# Parsed experiment parameters:
# experSubdir:tuning/bm25tune_text_text/bm25tune_k1=0.8_b=0.5
# extrTypeFinal:exper_desc/bm25tune_text_text/bm25tune_k1=0.8_b=0.5.json
# testOnly:1
# modelFinal:exper_desc/models/one_feat.model
# ========================================
# Started a process 1071634, working dir: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/bm25tune_text_text/bm25tune_k1=0.8_b=0.5
# Process log file: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/bm25tune_text_text/bm25tune_k1=0.8_b=0.5/exper.log
# Waiting for 1 child processes
# Process with pid=1071634 finished successfully.
# Parsed experiment parameters:
# experSubdir:tuning/bm25tune_text_text/bm25tune_k1=1_b=0.5
# extrTypeFinal:exper_desc/bm25tune_text_text/bm25tune_k1=1_b=0.5.json
# testOnly:1
# modelFinal:exper_desc/models/one_feat.model
# ========================================
# Started a process 1072178, working dir: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/bm25tune_text_text/bm25tune_k1=1_b=0.5
# Process log file: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/bm25tune_text_text/bm25tune_k1=1_b=0.5/exper.log
# Waiting for 1 child processes
# Process with pid=1072178 finished successfully.
# Parsed experiment parameters:
# experSubdir:tuning/bm25tune_text_text/bm25tune_k1=1.2_b=0.5
# extrTypeFinal:exper_desc/bm25tune_text_text/bm25tune_k1=1.2_b=0.5.json
# testOnly:1
# modelFinal:exper_desc/models/one_feat.model
# ========================================
# Started a process 1072694, working dir: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/bm25tune_text_text/bm25tune_k1=1.2_b=0.5
# Process log file: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/bm25tune_text_text/bm25tune_k1=1.2_b=0.5/exper.log
# Waiting for 1 child processes
# Process with pid=1072694 finished successfully.
# Parsed experiment parameters:
# experSubdir:tuning/bm25tune_text_text/bm25tune_k1=1.4_b=0.5
# extrTypeFinal:exper_desc/bm25tune_text_text/bm25tune_k1=1.4_b=0.5.json
# testOnly:1
# modelFinal:exper_desc/models/one_feat.model
# ========================================
# Started a process 1073213, working dir: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/bm25tune_text_text/bm25tune_k1=1.4_b=0.5
# Process log file: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/bm25tune_text_text/bm25tune_k1=1.4_b=0.5/exper.log
# Waiting for 1 child processes
# Process with pid=1073213 finished successfully.
# Parsed experiment parameters:
# experSubdir:tuning/bm25tune_text_text/bm25tune_k1=1.6_b=0.5
# extrTypeFinal:exper_desc/bm25tune_text_text/bm25tune_k1=1.6_b=0.5.json
# testOnly:1
# modelFinal:exper_desc/models/one_feat.model
# ========================================
# Started a process 1073743, working dir: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/bm25tune_text_text/bm25tune_k1=1.6_b=0.5
# Process log file: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/bm25tune_text_text/bm25tune_k1=1.6_b=0.5/exper.log
# Waiting for 1 child processes
# Process with pid=1073743 finished successfully.
# Parsed experiment parameters:
# experSubdir:tuning/bm25tune_text_text/bm25tune_k1=0.4_b=0.6
# extrTypeFinal:exper_desc/bm25tune_text_text/bm25tune_k1=0.4_b=0.6.json
# testOnly:1
# modelFinal:exper_desc/models/one_feat.model
# ========================================
# Started a process 1074260, working dir: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/bm25tune_text_text/bm25tune_k1=0.4_b=0.6
# Process log file: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/bm25tune_text_text/bm25tune_k1=0.4_b=0.6/exper.log
# Waiting for 1 child processes
# Process with pid=1074260 finished successfully.
# Parsed experiment parameters:
# experSubdir:tuning/bm25tune_text_text/bm25tune_k1=0.6_b=0.6
# extrTypeFinal:exper_desc/bm25tune_text_text/bm25tune_k1=0.6_b=0.6.json
# testOnly:1
# modelFinal:exper_desc/models/one_feat.model
# ========================================
# Started a process 1074776, working dir: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/bm25tune_text_text/bm25tune_k1=0.6_b=0.6
# Process log file: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/bm25tune_text_text/bm25tune_k1=0.6_b=0.6/exper.log
# Waiting for 1 child processes
# Process with pid=1074776 finished successfully.
# Parsed experiment parameters:
# experSubdir:tuning/bm25tune_text_text/bm25tune_k1=0.8_b=0.6
# extrTypeFinal:exper_desc/bm25tune_text_text/bm25tune_k1=0.8_b=0.6.json
# testOnly:1
# modelFinal:exper_desc/models/one_feat.model
# ========================================
# Started a process 1075293, working dir: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/bm25tune_text_text/bm25tune_k1=0.8_b=0.6
# Process log file: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/bm25tune_text_text/bm25tune_k1=0.8_b=0.6/exper.log
# Waiting for 1 child processes
# Process with pid=1075293 finished successfully.
# Parsed experiment parameters:
# experSubdir:tuning/bm25tune_text_text/bm25tune_k1=1_b=0.6
# extrTypeFinal:exper_desc/bm25tune_text_text/bm25tune_k1=1_b=0.6.json
# testOnly:1
# modelFinal:exper_desc/models/one_feat.model
# ========================================
# Started a process 1075813, working dir: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/bm25tune_text_text/bm25tune_k1=1_b=0.6
# Process log file: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/bm25tune_text_text/bm25tune_k1=1_b=0.6/exper.log
# Waiting for 1 child processes
# Process with pid=1075813 finished successfully.
# Parsed experiment parameters:
# experSubdir:tuning/bm25tune_text_text/bm25tune_k1=1.2_b=0.6
# extrTypeFinal:exper_desc/bm25tune_text_text/bm25tune_k1=1.2_b=0.6.json
# testOnly:1
# modelFinal:exper_desc/models/one_feat.model
# ========================================
# Started a process 1076339, working dir: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/bm25tune_text_text/bm25tune_k1=1.2_b=0.6
# Process log file: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/bm25tune_text_text/bm25tune_k1=1.2_b=0.6/exper.log
# Waiting for 1 child processes
# Process with pid=1076339 finished successfully.
# Parsed experiment parameters:
# experSubdir:tuning/bm25tune_text_text/bm25tune_k1=1.4_b=0.6
# extrTypeFinal:exper_desc/bm25tune_text_text/bm25tune_k1=1.4_b=0.6.json
# testOnly:1
# modelFinal:exper_desc/models/one_feat.model
# ========================================
# Started a process 1076855, working dir: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/bm25tune_text_text/bm25tune_k1=1.4_b=0.6
# Process log file: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/bm25tune_text_text/bm25tune_k1=1.4_b=0.6/exper.log
# Waiting for 1 child processes
# Process with pid=1076855 finished successfully.
# Parsed experiment parameters:
# experSubdir:tuning/bm25tune_text_text/bm25tune_k1=1.6_b=0.6
# extrTypeFinal:exper_desc/bm25tune_text_text/bm25tune_k1=1.6_b=0.6.json
# testOnly:1
# modelFinal:exper_desc/models/one_feat.model
# ========================================
# Started a process 1077419, working dir: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/bm25tune_text_text/bm25tune_k1=1.6_b=0.6
# Process log file: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/bm25tune_text_text/bm25tune_k1=1.6_b=0.6/exper.log
# Waiting for 1 child processes
# Process with pid=1077419 finished successfully.
# Parsed experiment parameters:
# experSubdir:tuning/bm25tune_text_text/bm25tune_k1=0.4_b=0.7
# extrTypeFinal:exper_desc/bm25tune_text_text/bm25tune_k1=0.4_b=0.7.json
# testOnly:1
# modelFinal:exper_desc/models/one_feat.model
# ========================================
# Started a process 1077937, working dir: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/bm25tune_text_text/bm25tune_k1=0.4_b=0.7
# Process log file: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/bm25tune_text_text/bm25tune_k1=0.4_b=0.7/exper.log
# Waiting for 1 child processes
# Process with pid=1077937 finished successfully.
# Parsed experiment parameters:
# experSubdir:tuning/bm25tune_text_text/bm25tune_k1=0.6_b=0.7
# extrTypeFinal:exper_desc/bm25tune_text_text/bm25tune_k1=0.6_b=0.7.json
# testOnly:1
# modelFinal:exper_desc/models/one_feat.model
# ========================================
# Started a process 1078456, working dir: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/bm25tune_text_text/bm25tune_k1=0.6_b=0.7
# Process log file: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/bm25tune_text_text/bm25tune_k1=0.6_b=0.7/exper.log
# Waiting for 1 child processes
# Process with pid=1078456 finished successfully.
# Parsed experiment parameters:
# experSubdir:tuning/bm25tune_text_text/bm25tune_k1=0.8_b=0.7
# extrTypeFinal:exper_desc/bm25tune_text_text/bm25tune_k1=0.8_b=0.7.json
# testOnly:1
# modelFinal:exper_desc/models/one_feat.model
# ========================================
# Started a process 1078993, working dir: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/bm25tune_text_text/bm25tune_k1=0.8_b=0.7
# Process log file: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/bm25tune_text_text/bm25tune_k1=0.8_b=0.7/exper.log
# Waiting for 1 child processes
# Process with pid=1078993 finished successfully.
# Parsed experiment parameters:
# experSubdir:tuning/bm25tune_text_text/bm25tune_k1=1_b=0.7
# extrTypeFinal:exper_desc/bm25tune_text_text/bm25tune_k1=1_b=0.7.json
# testOnly:1
# modelFinal:exper_desc/models/one_feat.model
# ========================================
# Started a process 1079508, working dir: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/bm25tune_text_text/bm25tune_k1=1_b=0.7
# Process log file: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/bm25tune_text_text/bm25tune_k1=1_b=0.7/exper.log
# Waiting for 1 child processes
# Process with pid=1079508 finished successfully.
# Parsed experiment parameters:
# experSubdir:tuning/bm25tune_text_text/bm25tune_k1=1.2_b=0.7
# extrTypeFinal:exper_desc/bm25tune_text_text/bm25tune_k1=1.2_b=0.7.json
# testOnly:1
# modelFinal:exper_desc/models/one_feat.model
# ========================================
# Started a process 1080026, working dir: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/bm25tune_text_text/bm25tune_k1=1.2_b=0.7
# Process log file: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/bm25tune_text_text/bm25tune_k1=1.2_b=0.7/exper.log
# Waiting for 1 child processes
# Process with pid=1080026 finished successfully.
# Parsed experiment parameters:
# experSubdir:tuning/bm25tune_text_text/bm25tune_k1=1.4_b=0.7
# extrTypeFinal:exper_desc/bm25tune_text_text/bm25tune_k1=1.4_b=0.7.json
# testOnly:1
# modelFinal:exper_desc/models/one_feat.model
# ========================================
# Started a process 1080559, working dir: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/bm25tune_text_text/bm25tune_k1=1.4_b=0.7
# Process log file: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/bm25tune_text_text/bm25tune_k1=1.4_b=0.7/exper.log
# Waiting for 1 child processes
# Process with pid=1080559 finished successfully.
# Parsed experiment parameters:
# experSubdir:tuning/bm25tune_text_text/bm25tune_k1=1.6_b=0.7
# extrTypeFinal:exper_desc/bm25tune_text_text/bm25tune_k1=1.6_b=0.7.json
# testOnly:1
# modelFinal:exper_desc/models/one_feat.model
# ========================================
# Started a process 1081074, working dir: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/bm25tune_text_text/bm25tune_k1=1.6_b=0.7
# Process log file: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/bm25tune_text_text/bm25tune_k1=1.6_b=0.7/exper.log
# Waiting for 1 child processes
# Process with pid=1081074 finished successfully.
# Parsed experiment parameters:
# experSubdir:tuning/bm25tune_text_text/bm25tune_k1=0.4_b=0.8
# extrTypeFinal:exper_desc/bm25tune_text_text/bm25tune_k1=0.4_b=0.8.json
# testOnly:1
# modelFinal:exper_desc/models/one_feat.model
# ========================================
# Started a process 1081602, working dir: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/bm25tune_text_text/bm25tune_k1=0.4_b=0.8
# Process log file: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/bm25tune_text_text/bm25tune_k1=0.4_b=0.8/exper.log
# Waiting for 1 child processes
# Process with pid=1081602 finished successfully.
# Parsed experiment parameters:
# experSubdir:tuning/bm25tune_text_text/bm25tune_k1=0.6_b=0.8
# extrTypeFinal:exper_desc/bm25tune_text_text/bm25tune_k1=0.6_b=0.8.json
# testOnly:1
# modelFinal:exper_desc/models/one_feat.model
# ========================================
# Started a process 1082135, working dir: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/bm25tune_text_text/bm25tune_k1=0.6_b=0.8
# Process log file: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/bm25tune_text_text/bm25tune_k1=0.6_b=0.8/exper.log
# Waiting for 1 child processes
# Process with pid=1082135 finished successfully.
# Parsed experiment parameters:
# experSubdir:tuning/bm25tune_text_text/bm25tune_k1=0.8_b=0.8
# extrTypeFinal:exper_desc/bm25tune_text_text/bm25tune_k1=0.8_b=0.8.json
# testOnly:1
# modelFinal:exper_desc/models/one_feat.model
# ========================================
# Started a process 1082680, working dir: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/bm25tune_text_text/bm25tune_k1=0.8_b=0.8
# Process log file: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/bm25tune_text_text/bm25tune_k1=0.8_b=0.8/exper.log
# Waiting for 1 child processes
# Process with pid=1082680 finished successfully.
# Parsed experiment parameters:
# experSubdir:tuning/bm25tune_text_text/bm25tune_k1=1_b=0.8
# extrTypeFinal:exper_desc/bm25tune_text_text/bm25tune_k1=1_b=0.8.json
# testOnly:1
# modelFinal:exper_desc/models/one_feat.model
# ========================================
# Started a process 1083196, working dir: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/bm25tune_text_text/bm25tune_k1=1_b=0.8
# Process log file: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/bm25tune_text_text/bm25tune_k1=1_b=0.8/exper.log
# Waiting for 1 child processes
# Process with pid=1083196 finished successfully.
# Parsed experiment parameters:
# experSubdir:tuning/bm25tune_text_text/bm25tune_k1=1.2_b=0.8
# extrTypeFinal:exper_desc/bm25tune_text_text/bm25tune_k1=1.2_b=0.8.json
# testOnly:1
# modelFinal:exper_desc/models/one_feat.model
# ========================================
# Started a process 1083724, working dir: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/bm25tune_text_text/bm25tune_k1=1.2_b=0.8
# Process log file: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/bm25tune_text_text/bm25tune_k1=1.2_b=0.8/exper.log
# Waiting for 1 child processes
# Process with pid=1083724 finished successfully.
# Parsed experiment parameters:
# experSubdir:tuning/bm25tune_text_text/bm25tune_k1=1.4_b=0.8
# extrTypeFinal:exper_desc/bm25tune_text_text/bm25tune_k1=1.4_b=0.8.json
# testOnly:1
# modelFinal:exper_desc/models/one_feat.model
# ========================================
# Started a process 1084247, working dir: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/bm25tune_text_text/bm25tune_k1=1.4_b=0.8
# Process log file: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/bm25tune_text_text/bm25tune_k1=1.4_b=0.8/exper.log
# Waiting for 1 child processes
# Process with pid=1084247 finished successfully.
# Parsed experiment parameters:
# experSubdir:tuning/bm25tune_text_text/bm25tune_k1=1.6_b=0.8
# extrTypeFinal:exper_desc/bm25tune_text_text/bm25tune_k1=1.6_b=0.8.json
# testOnly:1
# modelFinal:exper_desc/models/one_feat.model
# ========================================
# Started a process 1084767, working dir: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/bm25tune_text_text/bm25tune_k1=1.6_b=0.8
# Process log file: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/bm25tune_text_text/bm25tune_k1=1.6_b=0.8/exper.log
# Waiting for 1 child processes
# Process with pid=1084767 finished successfully.
# Parsed experiment parameters:
# experSubdir:tuning/bm25tune_text_text/bm25tune_k1=0.4_b=0.9
# extrTypeFinal:exper_desc/bm25tune_text_text/bm25tune_k1=0.4_b=0.9.json
# testOnly:1
# modelFinal:exper_desc/models/one_feat.model
# ========================================
# Started a process 1085289, working dir: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/bm25tune_text_text/bm25tune_k1=0.4_b=0.9
# Process log file: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/bm25tune_text_text/bm25tune_k1=0.4_b=0.9/exper.log
# Waiting for 1 child processes
# Process with pid=1085289 finished successfully.
# Parsed experiment parameters:
# experSubdir:tuning/bm25tune_text_text/bm25tune_k1=0.6_b=0.9
# extrTypeFinal:exper_desc/bm25tune_text_text/bm25tune_k1=0.6_b=0.9.json
# testOnly:1
# modelFinal:exper_desc/models/one_feat.model
# ========================================
# Started a process 1085820, working dir: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/bm25tune_text_text/bm25tune_k1=0.6_b=0.9
# Process log file: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/bm25tune_text_text/bm25tune_k1=0.6_b=0.9/exper.log
# Waiting for 1 child processes
# Process with pid=1085820 finished successfully.
# Parsed experiment parameters:
# experSubdir:tuning/bm25tune_text_text/bm25tune_k1=0.8_b=0.9
# extrTypeFinal:exper_desc/bm25tune_text_text/bm25tune_k1=0.8_b=0.9.json
# testOnly:1
# modelFinal:exper_desc/models/one_feat.model
# ========================================
# Started a process 1086341, working dir: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/bm25tune_text_text/bm25tune_k1=0.8_b=0.9
# Process log file: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/bm25tune_text_text/bm25tune_k1=0.8_b=0.9/exper.log
# Waiting for 1 child processes
# Process with pid=1086341 finished successfully.
# Parsed experiment parameters:
# experSubdir:tuning/bm25tune_text_text/bm25tune_k1=1_b=0.9
# extrTypeFinal:exper_desc/bm25tune_text_text/bm25tune_k1=1_b=0.9.json
# testOnly:1
# modelFinal:exper_desc/models/one_feat.model
# ========================================
# Started a process 1086858, working dir: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/bm25tune_text_text/bm25tune_k1=1_b=0.9
# Process log file: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/bm25tune_text_text/bm25tune_k1=1_b=0.9/exper.log
# Waiting for 1 child processes
# Process with pid=1086858 finished successfully.
# Parsed experiment parameters:
# experSubdir:tuning/bm25tune_text_text/bm25tune_k1=1.2_b=0.9
# extrTypeFinal:exper_desc/bm25tune_text_text/bm25tune_k1=1.2_b=0.9.json
# testOnly:1
# modelFinal:exper_desc/models/one_feat.model
# ========================================
# Started a process 1087512, working dir: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/bm25tune_text_text/bm25tune_k1=1.2_b=0.9
# Process log file: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/bm25tune_text_text/bm25tune_k1=1.2_b=0.9/exper.log
# Waiting for 1 child processes
# Process with pid=1087512 finished successfully.
# Parsed experiment parameters:
# experSubdir:tuning/bm25tune_text_text/bm25tune_k1=1.4_b=0.9
# extrTypeFinal:exper_desc/bm25tune_text_text/bm25tune_k1=1.4_b=0.9.json
# testOnly:1
# modelFinal:exper_desc/models/one_feat.model
# ========================================
# Started a process 1088059, working dir: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/bm25tune_text_text/bm25tune_k1=1.4_b=0.9
# Process log file: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/bm25tune_text_text/bm25tune_k1=1.4_b=0.9/exper.log
# Waiting for 1 child processes
# Process with pid=1088059 finished successfully.
# Parsed experiment parameters:
# experSubdir:tuning/bm25tune_text_text/bm25tune_k1=1.6_b=0.9
# extrTypeFinal:exper_desc/bm25tune_text_text/bm25tune_k1=1.6_b=0.9.json
# testOnly:1
# modelFinal:exper_desc/models/one_feat.model
# ========================================
# Started a process 1088579, working dir: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/bm25tune_text_text/bm25tune_k1=1.6_b=0.9
# Process log file: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/bm25tune_text_text/bm25tune_k1=1.6_b=0.9/exper.log
# Waiting for 1 child processes
# Process with pid=1088579 finished successfully.
# Parsed experiment parameters:
# experSubdir:tuning/bm25tune_text_text/bm25tune_k1=0.4_b=1
# extrTypeFinal:exper_desc/bm25tune_text_text/bm25tune_k1=0.4_b=1.json
# testOnly:1
# modelFinal:exper_desc/models/one_feat.model
# ========================================
# Started a process 1089111, working dir: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/bm25tune_text_text/bm25tune_k1=0.4_b=1
# Process log file: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/bm25tune_text_text/bm25tune_k1=0.4_b=1/exper.log
# Waiting for 1 child processes
# Process with pid=1089111 finished successfully.
# Parsed experiment parameters:
# experSubdir:tuning/bm25tune_text_text/bm25tune_k1=0.6_b=1
# extrTypeFinal:exper_desc/bm25tune_text_text/bm25tune_k1=0.6_b=1.json
# testOnly:1
# modelFinal:exper_desc/models/one_feat.model
# ========================================
# Started a process 1089630, working dir: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/bm25tune_text_text/bm25tune_k1=0.6_b=1
# Process log file: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/bm25tune_text_text/bm25tune_k1=0.6_b=1/exper.log
# Waiting for 1 child processes
# Process with pid=1089630 finished successfully.
# Parsed experiment parameters:
# experSubdir:tuning/bm25tune_text_text/bm25tune_k1=0.8_b=1
# extrTypeFinal:exper_desc/bm25tune_text_text/bm25tune_k1=0.8_b=1.json
# testOnly:1
# modelFinal:exper_desc/models/one_feat.model
# ========================================
# Started a process 1090149, working dir: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/bm25tune_text_text/bm25tune_k1=0.8_b=1
# Process log file: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/bm25tune_text_text/bm25tune_k1=0.8_b=1/exper.log
# Waiting for 1 child processes
# Process with pid=1090149 finished successfully.
# Parsed experiment parameters:
# experSubdir:tuning/bm25tune_text_text/bm25tune_k1=1_b=1
# extrTypeFinal:exper_desc/bm25tune_text_text/bm25tune_k1=1_b=1.json
# testOnly:1
# modelFinal:exper_desc/models/one_feat.model
# ========================================
# Started a process 1090680, working dir: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/bm25tune_text_text/bm25tune_k1=1_b=1
# Process log file: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/bm25tune_text_text/bm25tune_k1=1_b=1/exper.log
# Waiting for 1 child processes
# Process with pid=1090680 finished successfully.
# Parsed experiment parameters:
# experSubdir:tuning/bm25tune_text_text/bm25tune_k1=1.2_b=1
# extrTypeFinal:exper_desc/bm25tune_text_text/bm25tune_k1=1.2_b=1.json
# testOnly:1
# modelFinal:exper_desc/models/one_feat.model
# ========================================
# Started a process 1091200, working dir: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/bm25tune_text_text/bm25tune_k1=1.2_b=1
# Process log file: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/bm25tune_text_text/bm25tune_k1=1.2_b=1/exper.log
# Waiting for 1 child processes
# Process with pid=1091200 finished successfully.
# Parsed experiment parameters:
# experSubdir:tuning/bm25tune_text_text/bm25tune_k1=1.4_b=1
# extrTypeFinal:exper_desc/bm25tune_text_text/bm25tune_k1=1.4_b=1.json
# testOnly:1
# modelFinal:exper_desc/models/one_feat.model
# ========================================
# Started a process 1091717, working dir: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/bm25tune_text_text/bm25tune_k1=1.4_b=1
# Process log file: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/bm25tune_text_text/bm25tune_k1=1.4_b=1/exper.log
# Waiting for 1 child processes
# Process with pid=1091717 finished successfully.
# Parsed experiment parameters:
# experSubdir:tuning/bm25tune_text_text/bm25tune_k1=1.6_b=1
# extrTypeFinal:exper_desc/bm25tune_text_text/bm25tune_k1=1.6_b=1.json
# testOnly:1
# modelFinal:exper_desc/models/one_feat.model
# ========================================
# Started a process 1092249, working dir: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/bm25tune_text_text/bm25tune_k1=1.6_b=1
# Process log file: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/bm25tune_text_text/bm25tune_k1=1.6_b=1/exper.log
# Waiting for 1 child processes
# Process with pid=1092249 finished successfully.
# Waiting for 0 child processes
# ================================================================================
# 56 experiments executed
# 0 experiments failed
# ================================================================================

# %% [markdown]
# By default, experiments are run in the background: In fact, there can be more than one experiment run. However, for debugging purposes, one can run experiments in the foreground by specifying the option -no_separate_shell.
#
# Furthermore, the script scripts/exper/run_experiments.sh has a number of parameters, which might be worth tweaking. In particular, for "shallow" relevance pools, one can use default number of candidates (which is small). However, for queries with a lot of relevance judgments, it makes sense to slightly increase the number of top candidate entries that are used to obtain a fusion model (parameter -train_cand_qty).
#
# Now, let us obtain experimental results and find the best configuration with respect to the Mean Average Precision (MAP), which should be nearly equal to 0.3501:

# %%
# !./report/get_exper_results.sh \
  wikipedia_dpr_nq_sample \
  exper_desc/bm25tune_text_text.json \
  bm25tune.tsv \
  -test_part dev \
  -flt_cand_qty 250 \
  -print_best_metr map
# Out:
# Using collection root: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections
# Including only runs that generated 250 candidate records
# Best results for metric map:
# Value: 0.185800
# Result sub-dir: tuning/bm25tune_text_text/bm25tune_k1=0.8_b=0.3

# %% [markdown]
# ## Tuning a fusion of IBM Model 1 and BM25
#
# IBM Model 1 has quite a few parameters and can benefit from tuning as well.
# Rather than tuning IBM Model 1 alone, we tune its fusion with the BM25 score for the field
# `text`. Here we use optimal BM25 coefficients __obtained in the previous experiment__.
# Model 1 descriptors are going to be created for the field `text_bert_tok`:

# %%
# !./gen_exper_desc/gen_model1_exper_json_desc.py \
  -k1 0.6 -b 0.3  \
  --exper_subdir tuning \
  --query_field_name text_bert_tok \
  --index_field_name text_bert_tok \
  --outdir $COLLECT_ROOT/wikipedia_dpr_nq_sample/exper_desc/ \
  --rel_desc_path exper_desc
# Out:
# Namespace(outdir='/tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/exper_desc/', rel_desc_path='exper_desc', exper_subdir='tuning', index_field_name='text_bert_tok', query_field_name='text_bert_tok', cand_prov_uri=None, cand_prov_add_conf=None, cand_prov_qty=None, b=0.3, k1=0.6)

# %% [markdown]
# Now we can run tuning experiments where we train on `train_fusion` and test on `dev` (or `dev_official` if necessary):

# %%
# !./exper/run_experiments.sh \
  wikipedia_dpr_nq_sample \
  exper_desc/model1tune_text_bert_tok_text_bert_tok.json \
  -test_part dev -train_part train_fusion
# Out:
# Using collection root: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections
# The number of CPU cores:      16
# The number of || experiments: 1
# The number of threads:        16
# ================================================================================
# Experiment descriptor file:                                 /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/exper_desc/model1tune_text_bert_tok_text_bert_tok.json
# Default test set:                                           dev
# Number of parallel experiments:                             1
# Number of threads in feature extractors/query applications: 16
# ================================================================================
# Parsed experiment parameters:
# experSubdir:tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.05+probSelfTran=0.05
# extrTypeFinal:exper_desc/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.05+probSelfTran=0.05.json
# testOnly:0
# ========================================
# Started a process 1105951, working dir: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.05+probSelfTran=0.05
# Process log file: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.05+probSelfTran=0.05/exper.log
# Waiting for 1 child processes
# Process with pid=1105951 finished successfully.
# Parsed experiment parameters:
# experSubdir:tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.1+probSelfTran=0.05
# extrTypeFinal:exper_desc/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.1+probSelfTran=0.05.json
# testOnly:0
# ========================================
# Started a process 1106630, working dir: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.1+probSelfTran=0.05
# Process log file: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.1+probSelfTran=0.05/exper.log
# Waiting for 1 child processes
# Process with pid=1106630 finished successfully.
# Parsed experiment parameters:
# experSubdir:tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.15+probSelfTran=0.05
# extrTypeFinal:exper_desc/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.15+probSelfTran=0.05.json
# testOnly:0
# ========================================
# Started a process 1107336, working dir: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.15+probSelfTran=0.05
# Process log file: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.15+probSelfTran=0.05/exper.log
# Waiting for 1 child processes
# Process with pid=1107336 finished successfully.
# Parsed experiment parameters:
# experSubdir:tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.25+probSelfTran=0.05
# extrTypeFinal:exper_desc/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.25+probSelfTran=0.05.json
# testOnly:0
# ========================================
# Started a process 1108005, working dir: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.25+probSelfTran=0.05
# Process log file: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.25+probSelfTran=0.05/exper.log
# Waiting for 1 child processes
# Process with pid=1108005 finished successfully.
# Parsed experiment parameters:
# experSubdir:tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.3+probSelfTran=0.05
# extrTypeFinal:exper_desc/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.3+probSelfTran=0.05.json
# testOnly:0
# ========================================
# Started a process 1108679, working dir: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.3+probSelfTran=0.05
# Process log file: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.3+probSelfTran=0.05/exper.log
# Waiting for 1 child processes
# Process with pid=1108679 finished successfully.
# Parsed experiment parameters:
# experSubdir:tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.35+probSelfTran=0.05
# extrTypeFinal:exper_desc/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.35+probSelfTran=0.05.json
# testOnly:0
# ========================================
# Started a process 1109378, working dir: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.35+probSelfTran=0.05
# Process log file: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.35+probSelfTran=0.05/exper.log
# Waiting for 1 child processes
# Process with pid=1109378 finished successfully.
# Parsed experiment parameters:
# experSubdir:tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.45+probSelfTran=0.05
# extrTypeFinal:exper_desc/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.45+probSelfTran=0.05.json
# testOnly:0
# ========================================
# Started a process 1110077, working dir: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.45+probSelfTran=0.05
# Process log file: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.45+probSelfTran=0.05/exper.log
# Waiting for 1 child processes
# Process with pid=1110077 finished successfully.
# Parsed experiment parameters:
# experSubdir:tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.5+probSelfTran=0.05
# extrTypeFinal:exper_desc/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.5+probSelfTran=0.05.json
# testOnly:0
# ========================================
# Started a process 1110746, working dir: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.5+probSelfTran=0.05
# Process log file: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.5+probSelfTran=0.05/exper.log
# Waiting for 1 child processes
# Process with pid=1110746 finished successfully.
# Parsed experiment parameters:
# experSubdir:tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.05+probSelfTran=0.1
# extrTypeFinal:exper_desc/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.05+probSelfTran=0.1.json
# testOnly:0
# ========================================
# Started a process 1111412, working dir: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.05+probSelfTran=0.1
# Process log file: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.05+probSelfTran=0.1/exper.log
# Waiting for 1 child processes
# Process with pid=1111412 finished successfully.
# Parsed experiment parameters:
# experSubdir:tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.1+probSelfTran=0.1
# extrTypeFinal:exper_desc/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.1+probSelfTran=0.1.json
# testOnly:0
# ========================================
# Started a process 1112067, working dir: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.1+probSelfTran=0.1
# Process log file: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.1+probSelfTran=0.1/exper.log
# Waiting for 1 child processes
# Process with pid=1112067 finished successfully.
# Parsed experiment parameters:
# experSubdir:tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.15+probSelfTran=0.1
# extrTypeFinal:exper_desc/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.15+probSelfTran=0.1.json
# testOnly:0
# ========================================
# Started a process 1112907, working dir: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.15+probSelfTran=0.1
# Process log file: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.15+probSelfTran=0.1/exper.log
# Waiting for 1 child processes
# Process with pid=1112907 finished successfully.
# Parsed experiment parameters:
# experSubdir:tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.25+probSelfTran=0.1
# extrTypeFinal:exper_desc/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.25+probSelfTran=0.1.json
# testOnly:0
# ========================================
# Started a process 1113576, working dir: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.25+probSelfTran=0.1
# Process log file: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.25+probSelfTran=0.1/exper.log
# Waiting for 1 child processes
# Process with pid=1113576 finished successfully.
# Parsed experiment parameters:
# experSubdir:tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.3+probSelfTran=0.1
# extrTypeFinal:exper_desc/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.3+probSelfTran=0.1.json
# testOnly:0
# ========================================
# Started a process 1114258, working dir: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.3+probSelfTran=0.1
# Process log file: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.3+probSelfTran=0.1/exper.log
# Waiting for 1 child processes
# Process with pid=1114258 finished successfully.
# Parsed experiment parameters:
# experSubdir:tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.35+probSelfTran=0.1
# extrTypeFinal:exper_desc/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.35+probSelfTran=0.1.json
# testOnly:0
# ========================================
# Started a process 1114927, working dir: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.35+probSelfTran=0.1
# Process log file: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.35+probSelfTran=0.1/exper.log
# Waiting for 1 child processes
# Process with pid=1114927 finished successfully.
# Parsed experiment parameters:
# experSubdir:tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.45+probSelfTran=0.1
# extrTypeFinal:exper_desc/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.45+probSelfTran=0.1.json
# testOnly:0
# ========================================
# Started a process 1115603, working dir: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.45+probSelfTran=0.1
# Process log file: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.45+probSelfTran=0.1/exper.log
# Waiting for 1 child processes
# Process with pid=1115603 finished successfully.
# Parsed experiment parameters:
# experSubdir:tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.5+probSelfTran=0.1
# extrTypeFinal:exper_desc/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.5+probSelfTran=0.1.json
# testOnly:0
# ========================================
# Started a process 1116276, working dir: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.5+probSelfTran=0.1
# Process log file: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.5+probSelfTran=0.1/exper.log
# Waiting for 1 child processes
# Process with pid=1116276 finished successfully.
# Parsed experiment parameters:
# experSubdir:tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.05+probSelfTran=0.15
# extrTypeFinal:exper_desc/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.05+probSelfTran=0.15.json
# testOnly:0
# ========================================
# Started a process 1116982, working dir: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.05+probSelfTran=0.15
# Process log file: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.05+probSelfTran=0.15/exper.log
# Waiting for 1 child processes
# Process with pid=1116982 finished successfully.
# Parsed experiment parameters:
# experSubdir:tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.1+probSelfTran=0.15
# extrTypeFinal:exper_desc/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.1+probSelfTran=0.15.json
# testOnly:0
# ========================================
# Started a process 1117651, working dir: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.1+probSelfTran=0.15
# Process log file: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.1+probSelfTran=0.15/exper.log
# Waiting for 1 child processes
# Process with pid=1117651 finished successfully.
# Parsed experiment parameters:
# experSubdir:tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.15+probSelfTran=0.15
# extrTypeFinal:exper_desc/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.15+probSelfTran=0.15.json
# testOnly:0
# ========================================
# Started a process 1118330, working dir: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.15+probSelfTran=0.15
# Process log file: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.15+probSelfTran=0.15/exper.log
# Waiting for 1 child processes
# Process with pid=1118330 finished successfully.
# Parsed experiment parameters:
# experSubdir:tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.25+probSelfTran=0.15
# extrTypeFinal:exper_desc/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.25+probSelfTran=0.15.json
# testOnly:0
# ========================================
# Started a process 1118999, working dir: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.25+probSelfTran=0.15
# Process log file: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.25+probSelfTran=0.15/exper.log
# Waiting for 1 child processes
# Process with pid=1118999 finished successfully.
# Parsed experiment parameters:
# experSubdir:tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.3+probSelfTran=0.15
# extrTypeFinal:exper_desc/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.3+probSelfTran=0.15.json
# testOnly:0
# ========================================
# Started a process 1119675, working dir: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.3+probSelfTran=0.15
# Process log file: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.3+probSelfTran=0.15/exper.log
# Waiting for 1 child processes
# Process with pid=1119675 finished successfully.
# Parsed experiment parameters:
# experSubdir:tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.35+probSelfTran=0.15
# extrTypeFinal:exper_desc/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.35+probSelfTran=0.15.json
# testOnly:0
# ========================================
# Started a process 1120352, working dir: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.35+probSelfTran=0.15
# Process log file: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.35+probSelfTran=0.15/exper.log
# Waiting for 1 child processes
# Process with pid=1120352 finished successfully.
# Parsed experiment parameters:
# experSubdir:tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.45+probSelfTran=0.15
# extrTypeFinal:exper_desc/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.45+probSelfTran=0.15.json
# testOnly:0
# ========================================
# Started a process 1121026, working dir: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.45+probSelfTran=0.15
# Process log file: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.45+probSelfTran=0.15/exper.log
# Waiting for 1 child processes
# Process with pid=1121026 finished successfully.
# Parsed experiment parameters:
# experSubdir:tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.5+probSelfTran=0.15
# extrTypeFinal:exper_desc/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.5+probSelfTran=0.15.json
# testOnly:0
# ========================================
# Started a process 1121700, working dir: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.5+probSelfTran=0.15
# Process log file: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.5+probSelfTran=0.15/exper.log
# Waiting for 1 child processes
# Process with pid=1121700 finished successfully.
# Parsed experiment parameters:
# experSubdir:tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.05+probSelfTran=0.25
# extrTypeFinal:exper_desc/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.05+probSelfTran=0.25.json
# testOnly:0
# ========================================
# Started a process 1122409, working dir: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.05+probSelfTran=0.25
# Process log file: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.05+probSelfTran=0.25/exper.log
# Waiting for 1 child processes
# Process with pid=1122409 finished successfully.
# Parsed experiment parameters:
# experSubdir:tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.1+probSelfTran=0.25
# extrTypeFinal:exper_desc/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.1+probSelfTran=0.25.json
# testOnly:0
# ========================================
# Started a process 1123103, working dir: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.1+probSelfTran=0.25
# Process log file: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.1+probSelfTran=0.25/exper.log
# Waiting for 1 child processes
# Process with pid=1123103 finished successfully.
# Parsed experiment parameters:
# experSubdir:tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.15+probSelfTran=0.25
# extrTypeFinal:exper_desc/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.15+probSelfTran=0.25.json
# testOnly:0
# ========================================
# Started a process 1123779, working dir: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.15+probSelfTran=0.25
# Process log file: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.15+probSelfTran=0.25/exper.log
# Waiting for 1 child processes
# Process with pid=1123779 finished successfully.
# Parsed experiment parameters:
# experSubdir:tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.25+probSelfTran=0.25
# extrTypeFinal:exper_desc/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.25+probSelfTran=0.25.json
# testOnly:0
# ========================================
# Started a process 1124448, working dir: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.25+probSelfTran=0.25
# Process log file: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.25+probSelfTran=0.25/exper.log
# Waiting for 1 child processes
# Process with pid=1124448 finished successfully.
# Parsed experiment parameters:
# experSubdir:tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.3+probSelfTran=0.25
# extrTypeFinal:exper_desc/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.3+probSelfTran=0.25.json
# testOnly:0
# ========================================
# Started a process 1125125, working dir: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.3+probSelfTran=0.25
# Process log file: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.3+probSelfTran=0.25/exper.log
# Waiting for 1 child processes
# Process with pid=1125125 finished successfully.
# Parsed experiment parameters:
# experSubdir:tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.35+probSelfTran=0.25
# extrTypeFinal:exper_desc/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.35+probSelfTran=0.25.json
# testOnly:0
# ========================================
# Started a process 1125801, working dir: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.35+probSelfTran=0.25
# Process log file: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.35+probSelfTran=0.25/exper.log
# Waiting for 1 child processes
# Process with pid=1125801 finished successfully.
# Parsed experiment parameters:
# experSubdir:tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.45+probSelfTran=0.25
# extrTypeFinal:exper_desc/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.45+probSelfTran=0.25.json
# testOnly:0
# ========================================
# Started a process 1126595, working dir: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.45+probSelfTran=0.25
# Process log file: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.45+probSelfTran=0.25/exper.log
# Waiting for 1 child processes
# Process with pid=1126595 finished successfully.
# Parsed experiment parameters:
# experSubdir:tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.5+probSelfTran=0.25
# extrTypeFinal:exper_desc/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.5+probSelfTran=0.25.json
# testOnly:0
# ========================================
# Started a process 1127299, working dir: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.5+probSelfTran=0.25
# Process log file: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.5+probSelfTran=0.25/exper.log
# Waiting for 1 child processes
# Process with pid=1127299 finished successfully.
# Parsed experiment parameters:
# experSubdir:tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.05+probSelfTran=0.3
# extrTypeFinal:exper_desc/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.05+probSelfTran=0.3.json
# testOnly:0
# ========================================
# Started a process 1127980, working dir: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.05+probSelfTran=0.3
# Process log file: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.05+probSelfTran=0.3/exper.log
# Waiting for 1 child processes
# Process with pid=1127980 finished successfully.
# Parsed experiment parameters:
# experSubdir:tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.1+probSelfTran=0.3
# extrTypeFinal:exper_desc/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.1+probSelfTran=0.3.json
# testOnly:0
# ========================================
# Started a process 1128656, working dir: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.1+probSelfTran=0.3
# Process log file: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.1+probSelfTran=0.3/exper.log
# Waiting for 1 child processes
# Process with pid=1128656 finished successfully.
# Parsed experiment parameters:
# experSubdir:tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.15+probSelfTran=0.3
# extrTypeFinal:exper_desc/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.15+probSelfTran=0.3.json
# testOnly:0
# ========================================
# Started a process 1129331, working dir: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.15+probSelfTran=0.3
# Process log file: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.15+probSelfTran=0.3/exper.log
# Waiting for 1 child processes
# Process with pid=1129331 finished successfully.
# Parsed experiment parameters:
# experSubdir:tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.25+probSelfTran=0.3
# extrTypeFinal:exper_desc/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.25+probSelfTran=0.3.json
# testOnly:0
# ========================================
# Started a process 1130014, working dir: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.25+probSelfTran=0.3
# Process log file: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.25+probSelfTran=0.3/exper.log
# Waiting for 1 child processes
# Process with pid=1130014 finished successfully.
# Parsed experiment parameters:
# experSubdir:tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.3+probSelfTran=0.3
# extrTypeFinal:exper_desc/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.3+probSelfTran=0.3.json
# testOnly:0
# ========================================
# Started a process 1130950, working dir: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.3+probSelfTran=0.3
# Process log file: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.3+probSelfTran=0.3/exper.log
# Waiting for 1 child processes
# Process with pid=1130950 finished successfully.
# Parsed experiment parameters:
# experSubdir:tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.35+probSelfTran=0.3
# extrTypeFinal:exper_desc/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.35+probSelfTran=0.3.json
# testOnly:0
# ========================================
# Started a process 1131643, working dir: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.35+probSelfTran=0.3
# Process log file: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.35+probSelfTran=0.3/exper.log
# Waiting for 1 child processes
# Process with pid=1131643 finished successfully.
# Parsed experiment parameters:
# experSubdir:tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.45+probSelfTran=0.3
# extrTypeFinal:exper_desc/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.45+probSelfTran=0.3.json
# testOnly:0
# ========================================
# Started a process 1132397, working dir: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.45+probSelfTran=0.3
# Process log file: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.45+probSelfTran=0.3/exper.log
# Waiting for 1 child processes
# Process with pid=1132397 finished successfully.
# Parsed experiment parameters:
# experSubdir:tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.5+probSelfTran=0.3
# extrTypeFinal:exper_desc/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.5+probSelfTran=0.3.json
# testOnly:0
# ========================================
# Started a process 1133139, working dir: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.5+probSelfTran=0.3
# Process log file: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.5+probSelfTran=0.3/exper.log
# Waiting for 1 child processes
# Process with pid=1133139 finished successfully.
# Parsed experiment parameters:
# experSubdir:tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.05+probSelfTran=0.35
# extrTypeFinal:exper_desc/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.05+probSelfTran=0.35.json
# testOnly:0
# ========================================
# Started a process 1133837, working dir: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.05+probSelfTran=0.35
# Process log file: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.05+probSelfTran=0.35/exper.log
# Waiting for 1 child processes
# Process with pid=1133837 finished successfully.
# Parsed experiment parameters:
# experSubdir:tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.1+probSelfTran=0.35
# extrTypeFinal:exper_desc/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.1+probSelfTran=0.35.json
# testOnly:0
# ========================================
# Started a process 1134510, working dir: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.1+probSelfTran=0.35
# Process log file: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.1+probSelfTran=0.35/exper.log
# Waiting for 1 child processes
# Process with pid=1134510 finished successfully.
# Parsed experiment parameters:
# experSubdir:tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.15+probSelfTran=0.35
# extrTypeFinal:exper_desc/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.15+probSelfTran=0.35.json
# testOnly:0
# ========================================
# Started a process 1135199, working dir: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.15+probSelfTran=0.35
# Process log file: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.15+probSelfTran=0.35/exper.log
# Waiting for 1 child processes
# Process with pid=1135199 finished successfully.
# Parsed experiment parameters:
# experSubdir:tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.25+probSelfTran=0.35
# extrTypeFinal:exper_desc/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.25+probSelfTran=0.35.json
# testOnly:0
# ========================================
# Started a process 1135889, working dir: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.25+probSelfTran=0.35
# Process log file: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.25+probSelfTran=0.35/exper.log
# Waiting for 1 child processes
# Process with pid=1135889 finished successfully.
# Parsed experiment parameters:
# experSubdir:tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.3+probSelfTran=0.35
# extrTypeFinal:exper_desc/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.3+probSelfTran=0.35.json
# testOnly:0
# ========================================
# Started a process 1136639, working dir: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.3+probSelfTran=0.35
# Process log file: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.3+probSelfTran=0.35/exper.log
# Waiting for 1 child processes
# Process with pid=1136639 finished successfully.
# Parsed experiment parameters:
# experSubdir:tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.35+probSelfTran=0.35
# extrTypeFinal:exper_desc/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.35+probSelfTran=0.35.json
# testOnly:0
# ========================================
# Started a process 1137319, working dir: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.35+probSelfTran=0.35
# Process log file: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.35+probSelfTran=0.35/exper.log
# Waiting for 1 child processes
# Process with pid=1137319 finished successfully.
# Parsed experiment parameters:
# experSubdir:tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.45+probSelfTran=0.35
# extrTypeFinal:exper_desc/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.45+probSelfTran=0.35.json
# testOnly:0
# ========================================
# Started a process 1138085, working dir: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.45+probSelfTran=0.35
# Process log file: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.45+probSelfTran=0.35/exper.log
# Waiting for 1 child processes
# Process with pid=1138085 finished successfully.
# Parsed experiment parameters:
# experSubdir:tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.5+probSelfTran=0.35
# extrTypeFinal:exper_desc/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.5+probSelfTran=0.35.json
# testOnly:0
# ========================================
# Started a process 1138770, working dir: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.5+probSelfTran=0.35
# Process log file: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.5+probSelfTran=0.35/exper.log
# Waiting for 1 child processes
# Process with pid=1138770 finished successfully.
# Parsed experiment parameters:
# experSubdir:tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.05+probSelfTran=0.45
# extrTypeFinal:exper_desc/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.05+probSelfTran=0.45.json
# testOnly:0
# ========================================
# Started a process 1139498, working dir: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.05+probSelfTran=0.45
# Process log file: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.05+probSelfTran=0.45/exper.log
# Waiting for 1 child processes
# Process with pid=1139498 finished successfully.
# Parsed experiment parameters:
# experSubdir:tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.1+probSelfTran=0.45
# extrTypeFinal:exper_desc/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.1+probSelfTran=0.45.json
# testOnly:0
# ========================================
# Started a process 1140220, working dir: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.1+probSelfTran=0.45
# Process log file: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.1+probSelfTran=0.45/exper.log
# Waiting for 1 child processes
# ...
# Parsed experiment parameters:
# experSubdir:tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.15+probSelfTran=0.75
# extrTypeFinal:exper_desc/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.15+probSelfTran=0.75.json
# testOnly:0
# ========================================
# Started a process 1175550, working dir: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.15+probSelfTran=0.75
# Process log file: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.15+probSelfTran=0.75/exper.log
# Waiting for 1 child processes
# Process with pid=1175550 finished successfully.
# Parsed experiment parameters:
# experSubdir:tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.25+probSelfTran=0.75
# extrTypeFinal:exper_desc/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.25+probSelfTran=0.75.json
# testOnly:0
# ========================================
# Started a process 1176765, working dir: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.25+probSelfTran=0.75
# Process log file: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.25+probSelfTran=0.75/exper.log
# Waiting for 1 child processes
# Process with pid=1176765 finished successfully.
# Parsed experiment parameters:
# experSubdir:tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.3+probSelfTran=0.75
# extrTypeFinal:exper_desc/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.3+probSelfTran=0.75.json
# testOnly:0
# ========================================
# Started a process 1177597, working dir: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.3+probSelfTran=0.75
# Process log file: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.3+probSelfTran=0.75/exper.log
# Waiting for 1 child processes
# Process with pid=1177597 finished successfully.
# Parsed experiment parameters:
# experSubdir:tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.35+probSelfTran=0.75
# extrTypeFinal:exper_desc/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.35+probSelfTran=0.75.json
# testOnly:0
# ========================================
# Started a process 1178488, working dir: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.35+probSelfTran=0.75
# Process log file: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.35+probSelfTran=0.75/exper.log
# Waiting for 1 child processes
# Process with pid=1178488 finished successfully.
# Parsed experiment parameters:
# experSubdir:tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.45+probSelfTran=0.75
# extrTypeFinal:exper_desc/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.45+probSelfTran=0.75.json
# testOnly:0
# ========================================
# Started a process 1179456, working dir: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.45+probSelfTran=0.75
# Process log file: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.45+probSelfTran=0.75/exper.log
# Waiting for 1 child processes
# Process with pid=1179456 finished successfully.
# Parsed experiment parameters:
# experSubdir:tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.5+probSelfTran=0.75
# extrTypeFinal:exper_desc/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.5+probSelfTran=0.75.json
# testOnly:0
# ========================================
# Started a process 1180157, working dir: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.5+probSelfTran=0.75
# Process log file: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.5+probSelfTran=0.75/exper.log
# Waiting for 1 child processes
# Process with pid=1180157 finished successfully.
# Parsed experiment parameters:
# experSubdir:tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.05+probSelfTran=0.6
# extrTypeFinal:exper_desc/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.05+probSelfTran=0.6.json
# testOnly:0
# ========================================
# Experimental directory already exists (ignoring): /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.05+probSelfTran=0.6
# Parsed experiment parameters:
# experSubdir:tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.05+probSelfTran=0.7
# extrTypeFinal:exper_desc/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.05+probSelfTran=0.7.json
# testOnly:0
# ========================================
# Experimental directory already exists (ignoring): /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.05+probSelfTran=0.7
# Parsed experiment parameters:
# experSubdir:tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.05+probSelfTran=0.8
# extrTypeFinal:exper_desc/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.05+probSelfTran=0.8.json
# testOnly:0
# ========================================
# Started a process 1181458, working dir: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.05+probSelfTran=0.8
# Process log file: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.05+probSelfTran=0.8/exper.log
# Waiting for 1 child processes
# Process with pid=1181458 finished successfully.
# Parsed experiment parameters:
# experSubdir:tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.05+probSelfTran=0.9
# extrTypeFinal:exper_desc/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.05+probSelfTran=0.9.json
# testOnly:0
# ========================================
# Started a process 1182269, working dir: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.05+probSelfTran=0.9
# Process log file: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.05+probSelfTran=0.9/exper.log
# Waiting for 1 child processes
# Process with pid=1182269 finished successfully.
# Parsed experiment parameters:
# experSubdir:tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.01+probSelfTran=0.9
# extrTypeFinal:exper_desc/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.01+probSelfTran=0.9.json
# testOnly:0
# ========================================
# Started a process 1183283, working dir: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.01+probSelfTran=0.9
# Process log file: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.01+probSelfTran=0.9/exper.log
# Waiting for 1 child processes
# Process with pid=1183283 finished successfully.
# Parsed experiment parameters:
# experSubdir:tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.001+probSelfTran=0.9
# extrTypeFinal:exper_desc/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.001+probSelfTran=0.9.json
# testOnly:0
# ========================================
# Started a process 1184147, working dir: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.001+probSelfTran=0.9
# Process log file: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.001+probSelfTran=0.9/exper.log
# Waiting for 1 child processes
# Process with pid=1184147 finished successfully.
# Parsed experiment parameters:
# experSubdir:tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.0001+probSelfTran=0.9
# extrTypeFinal:exper_desc/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.0001+probSelfTran=0.9.json
# testOnly:0
# ========================================
# Started a process 1184835, working dir: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.0001+probSelfTran=0.9
# Process log file: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=0.0001+probSelfTran=0.9/exper.log
# Waiting for 1 child processes
# Process with pid=1184835 finished successfully.
# Parsed experiment parameters:
# experSubdir:tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=1e-05+probSelfTran=0.9+minTranProb=0.001
# extrTypeFinal:exper_desc/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=1e-05+probSelfTran=0.9+minTranProb=0.001.json
# testOnly:0
# ========================================
# Started a process 1185931, working dir: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=1e-05+probSelfTran=0.9+minTranProb=0.001
# Process log file: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=1e-05+probSelfTran=0.9+minTranProb=0.001/exper.log
# Waiting for 1 child processes
# Process with pid=1185931 finished successfully.
# Parsed experiment parameters:
# experSubdir:tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=1e-05+probSelfTran=0.9+minTranProb=0.0001
# extrTypeFinal:exper_desc/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=1e-05+probSelfTran=0.9+minTranProb=0.0001.json
# testOnly:0
# ========================================
# Started a process 1186702, working dir: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=1e-05+probSelfTran=0.9+minTranProb=0.0001
# Process log file: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=1e-05+probSelfTran=0.9+minTranProb=0.0001/exper.log
# Waiting for 1 child processes
# Process with pid=1186702 finished successfully.
# Parsed experiment parameters:
# experSubdir:tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=1e-05+probSelfTran=0.9+minTranProb=0.0005
# extrTypeFinal:exper_desc/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=1e-05+probSelfTran=0.9+minTranProb=0.0005.json
# testOnly:0
# ========================================
# Started a process 1187686, working dir: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=1e-05+probSelfTran=0.9+minTranProb=0.0005
# Process log file: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=1e-05+probSelfTran=0.9+minTranProb=0.0005/exper.log
# Waiting for 1 child processes
# Process with pid=1187686 finished successfully.
# Parsed experiment parameters:
# experSubdir:tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=1e-05+probSelfTran=0.9+minTranProb=0.00025
# extrTypeFinal:exper_desc/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=1e-05+probSelfTran=0.9+minTranProb=0.00025.json
# testOnly:0
# ========================================
# Started a process 1188566, working dir: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=1e-05+probSelfTran=0.9+minTranProb=0.00025
# Process log file: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/results/dev/tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=1e-05+probSelfTran=0.9+minTranProb=0.00025/exper.log
# Waiting for 1 child processes
# Process with pid=1188566 finished successfully.
# Waiting for 0 child processes
# ================================================================================
# 105 experiments executed
# 0 experiments failed
# ================================================================================

# %% [markdown]
# Obtaining the best configuration with respect to MAP:

# %%
# !./report/get_exper_results.sh \
  wikipedia_dpr_nq_sample \
  exper_desc/model1tune_text_bert_tok_text_bert_tok.json \
  model1_text_bert_tok_tune.tsv \
  -test_part dev \
  -flt_cand_qty 250 \
  -print_best_metr map
# Out:
# Using collection root: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections
# Including only runs that generated 250 candidate records
# Best results for metric map:
# Value: 0.282400
# Result sub-dir: tuning/model1tune_text_bert_tok_text_bert_tok/bm25=text+model1=text_bert_tok+lambda=1e-05+probSelfTran=0.9+minTranProb=0.0005
