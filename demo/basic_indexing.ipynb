# %% [markdown]
# # Indexing notebook

# %% [markdown]
# ### Two things to do before we start:
# 1. Point environment variable `COLLECT_ROOT` to the collection root.
# 2. Change directory to the location of installed scripts/binaries

# %%
import os
COLLECT_ROOT = os.path.abspath("collections")
os.makedirs(COLLECT_ROOT, exist_ok=True)
# %env COLLECT_ROOT={COLLECT_ROOT}
print(COLLECT_ROOT)
# Out:
# env: COLLECT_ROOT=/tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections
# /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections

# %%
# %cd ./flexneuart_scripts/
# !bash -c "echo COLLECT_ROOT=$COLLECT_ROOT"
# Out:
# /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/flexneuart_scripts
# COLLECT_ROOT=/tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections

# %% [markdown]
# ### Lucene indexer options

# %%
# !./index/create_lucene_index.sh
# Out:
# Using collection root: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections
# Specify collection sub-directory, e.g., msmarco_pass (1st arg)
# Usage: <collection> [additional options]
# Additional options:
# -h print help
# -exact_match create index for exact match
# -ignore_missing_field ignore missing fields (use cautiously, fields normally should not be missing
# -index_field indexing field name (default text)
# -input_subdir input data sub-directory (default input_data)
# -index_subdir index subdirectory (default lucene_index)

# %% [markdown]
# By default Lucene using the context of the field `text` to create the full-text index, which is stored in the sub-directory `lucene_index`, but it is possible to create an index for an exact match, use a content of a different field, or store the inde

# %% [markdown]
# ### Lucene index

# %%
# !./index/create_lucene_index.sh wikipedia_dpr_nq_sample
# Out:
# Using collection root: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections
# ==========================================================================
# Input data directory: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/input_data
# Index directory:      /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/lucene_index
# Index field name:     text
# Exact match param:
# Ignore missing field:
# ==========================================================================
# Checking input sub-directory: bitext
# Checking input sub-directory: dev
# Checking input sub-directory: dev_official
# Checking input sub-directory: pass_sample
# Found indexable data file: pass_sample/AnswerFields.jsonl.gz
# Checking input sub-directory: train_fusion
# Found query file: bitext/QuestionFields.jsonl
# Found query file: dev/QuestionFields.jsonl
# Found query file: dev_official/QuestionFields.jsonl
# Found query file: train_fusion/QuestionFields.jsonl
# Using the data input file: AnswerFields.jsonl.gz
# JAVA_OPTS=-Xms4070758k -Xmx28495306k -server
# [main] INFO edu.cmu.lti.oaqa.flexneuart.apps.LuceneIndexer - Creating a new Lucene index, maximum # of docs to process: 2147483647 index field name: text exact match? false
# [main] INFO edu.cmu.lti.oaqa.flexneuart.apps.LuceneIndexer - Input file name: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/input_data/pass_sample/AnswerFields.jsonl.gz
# [main] INFO edu.cmu.lti.oaqa.flexneuart.apps.LuceneIndexer - Indexed 100000 docs
# [main] INFO edu.cmu.lti.oaqa.flexneuart.apps.LuceneIndexer - Indexed 200000 docs
# [main] INFO edu.cmu.lti.oaqa.flexneuart.apps.LuceneIndexer - Indexed 300000 docs
# [main] INFO edu.cmu.lti.oaqa.flexneuart.apps.LuceneIndexer - Indexed 400000 docs
# [main] INFO edu.cmu.lti.oaqa.flexneuart.apps.LuceneIndexer - Indexed 500000 docs
# [main] INFO edu.cmu.lti.oaqa.flexneuart.apps.LuceneIndexer - Indexed 600000 docs
# [main] INFO edu.cmu.lti.oaqa.flexneuart.apps.LuceneIndexer - Indexed 700000 docs
# [main] INFO edu.cmu.lti.oaqa.flexneuart.apps.LuceneIndexer - Indexed 774392 docs

# %% [markdown]
# ### Forward indices

# %% [markdown]
# A forward index allows one to retrieve an original or parsed field content using a document identifier. The forward index can be stored using two foramts and two storage engines (mapdb and lucene). In most cases, default settings (we use `mapdb` directly) works well: It permis the fastest re-rankers when there is enough memory. When there is not enough memory, one can build using an option `-fwd_index_type offsetDict` possibly combined with `-fwd_index_store_type lucene`, which stores data records in a separate file and uses `mapdb` or `lucene` key-value index to store only offsets & lengths.
#
# There are four types of the field, which include:
# 1. two parsed textual field formats:
#     - Parsed text without positional information (bag-of-words): **parsedBOW**
#     - Parsed text with positional information: **parsedText**
# 2. original/unparsed/raw text: **textRaw**
# 3. binary (can be anything): **binary**
#
# The options are printed by the indexing script:

# %%
# !./index/create_fwd_index.sh
# Out:
# Using collection root: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections
# collection sub-directory, e.g., msmarco_pass (1st arg)
# Usage: <collection sub-directory, e.g., msmarco_pass> <field definition: examples: text:parsedBOW, text_unlemm:parsedText, text_raw:textRaw, dense_embed:binary> [additional options]
# Additional options:
# -h print help
# -clean remove the previous index
# -input_subdir input data sub-directory (default input_data)
# -index_subdir index subdirectory (default forward_index)
# -fwd_index_type forward index type: dataDict, offsetDict
# -fwd_index_store_type a forward backend storage type: lucene, mapdb
# -expect_doc_qty expected # of documents in the index

# %% [markdown]
# Here we create indices sequentially, but they can also be created **in parallel** (independently for each field):

# %%
# !for field_def in dense:binary text:parsedText \
                  text_unlemm:parsedText \
                  title:parsedBOW \
                  text_bert_tok:parsedText \
                  text_raw:textRaw ; do \
    ./index/create_fwd_index.sh wikipedia_dpr_nq_sample $field_def ; \
done
# Out:
# Using collection root: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections
# ==========================================================================
# Input data directory:      /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/input_data
# Forward index directory:   /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/forward_index
# Remove old index?:         0
# Field definition:          dense:binary
# Index type arguments:
# ==========================================================================
# Checking input sub-directory: bitext
# Checking input sub-directory: dev
# Checking input sub-directory: dev_official
# Checking input sub-directory: pass_sample
# Found indexable data file: pass_sample/AnswerFields.jsonl.gz
# Checking input sub-directory: train_fusion
# Found query file: bitext/QuestionFields.jsonl
# Found query file: dev/QuestionFields.jsonl
# Found query file: dev_official/QuestionFields.jsonl
# Found query file: train_fusion/QuestionFields.jsonl
# JAVA_OPTS=-Xms4070758k -Xmx28495306k -server
# [main] INFO edu.cmu.lti.oaqa.flexneuart.apps.BuildFwdIndexApp - Processing field: 'dense'
# [main] INFO edu.cmu.lti.oaqa.flexneuart.apps.BuildFwdIndexApp - Forward index type: dataDict
# [main] INFO edu.cmu.lti.oaqa.flexneuart.apps.BuildFwdIndexApp - Forward index storage type: mapdb
# [main] INFO edu.cmu.lti.oaqa.flexneuart.apps.BuildFwdIndexApp - Forward index field type: binary
# [main] INFO edu.cmu.lti.oaqa.flexneuart.fwdindx.MapDbBackend - MapDB opened for writing: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/forward_index/dense.mapdb_dataDict using expected # of entries: 1000000000
# [main] INFO edu.cmu.lti.oaqa.flexneuart.fwdindx.MapDbBackend - # of segments/block size/# of levels 30/32/5
# [main] INFO edu.cmu.lti.oaqa.flexneuart.fwdindx.ForwardIndex - Creating a new forward index, maximum # of docs to process: 2147483647
# [main] INFO edu.cmu.lti.oaqa.flexneuart.fwdindx.ForwardIndex - Processed 100000 documents
# [main] INFO edu.cmu.lti.oaqa.flexneuart.fwdindx.ForwardIndex - Processed 200000 documents
# [main] INFO edu.cmu.lti.oaqa.flexneuart.fwdindx.ForwardIndex - Processed 300000 documents
# [main] INFO edu.cmu.lti.oaqa.flexneuart.fwdindx.ForwardIndex - Processed 400000 documents
# [main] INFO edu.cmu.lti.oaqa.flexneuart.fwdindx.ForwardIndex - Processed 500000 documents
# [main] INFO edu.cmu.lti.oaqa.flexneuart.fwdindx.ForwardIndex - Processed 600000 documents
# [main] INFO edu.cmu.lti.oaqa.flexneuart.fwdindx.ForwardIndex - Processed 700000 documents
# [main] INFO edu.cmu.lti.oaqa.flexneuart.fwdindx.ForwardIndex - Finished processing file: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/input_data/pass_sample/AnswerFields.bin
# [main] INFO edu.cmu.lti.oaqa.flexneuart.fwdindx.ForwardIndex - Final statistics:
# [main] INFO edu.cmu.lti.oaqa.flexneuart.fwdindx.ForwardIndex - Number of documents 774392, total number of words 0, average reduction due to keeping only unique words 0,000000
# Using collection root: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections
# ==========================================================================
# Input data directory:      /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/input_data
# Forward index directory:   /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/forward_index
# Remove old index?:         0
# Field definition:          text:parsedText
# Index type arguments:
# ==========================================================================
# Checking input sub-directory: bitext
# Checking input sub-directory: dev
# Checking input sub-directory: dev_official
# Checking input sub-directory: pass_sample
# Found indexable data file: pass_sample/AnswerFields.jsonl.gz
# Checking input sub-directory: train_fusion
# Found query file: bitext/QuestionFields.jsonl
# Found query file: dev/QuestionFields.jsonl
# Found query file: dev_official/QuestionFields.jsonl
# Found query file: train_fusion/QuestionFields.jsonl
# JAVA_OPTS=-Xms4070758k -Xmx28495306k -server
# [main] INFO edu.cmu.lti.oaqa.flexneuart.apps.BuildFwdIndexApp - Processing field: 'text'
# [main] INFO edu.cmu.lti.oaqa.flexneuart.apps.BuildFwdIndexApp - Forward index type: dataDict
# [main] INFO edu.cmu.lti.oaqa.flexneuart.apps.BuildFwdIndexApp - Forward index storage type: mapdb
# [main] INFO edu.cmu.lti.oaqa.flexneuart.apps.BuildFwdIndexApp - Forward index field type: parsedText
# [main] INFO edu.cmu.lti.oaqa.flexneuart.fwdindx.MapDbBackend - MapDB opened for writing: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/forward_index/text.mapdb_dataDict using expected # of entries: 1000000000
# [main] INFO edu.cmu.lti.oaqa.flexneuart.fwdindx.MapDbBackend - # of segments/block size/# of levels 30/32/5
# [main] INFO edu.cmu.lti.oaqa.flexneuart.fwdindx.ForwardIndex - Creating a new forward index, maximum # of docs to process: 2147483647
# [main] INFO edu.cmu.lti.oaqa.flexneuart.fwdindx.ForwardIndex - Processed 100000 documents
# [main] INFO edu.cmu.lti.oaqa.flexneuart.fwdindx.ForwardIndex - Processed 200000 documents
# [main] INFO edu.cmu.lti.oaqa.flexneuart.fwdindx.ForwardIndex - Processed 300000 documents
# [main] INFO edu.cmu.lti.oaqa.flexneuart.fwdindx.ForwardIndex - Processed 400000 documents
# [main] INFO edu.cmu.lti.oaqa.flexneuart.fwdindx.ForwardIndex - Processed 500000 documents
# [main] INFO edu.cmu.lti.oaqa.flexneuart.fwdindx.ForwardIndex - Processed 600000 documents
# [main] INFO edu.cmu.lti.oaqa.flexneuart.fwdindx.ForwardIndex - Processed 700000 documents
# [main] INFO edu.cmu.lti.oaqa.flexneuart.fwdindx.ForwardIndex - Finished processing file: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/input_data/pass_sample/AnswerFields.jsonl.gz
# [main] INFO edu.cmu.lti.oaqa.flexneuart.fwdindx.ForwardIndex - Final statistics:
# [main] INFO edu.cmu.lti.oaqa.flexneuart.fwdindx.ForwardIndex - Number of documents 774392, total number of words 45938701, average reduction due to keeping only unique words 1,304842
# Using collection root: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections
# ==========================================================================
# Input data directory:      /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/input_data
# Forward index directory:   /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/forward_index
# Remove old index?:         0
# Field definition:          text_unlemm:parsedText
# Index type arguments:
# ==========================================================================
# Checking input sub-directory: bitext
# Checking input sub-directory: dev
# Checking input sub-directory: dev_official
# Checking input sub-directory: pass_sample
# Found indexable data file: pass_sample/AnswerFields.jsonl.gz
# Checking input sub-directory: train_fusion
# Found query file: bitext/QuestionFields.jsonl
# Found query file: dev/QuestionFields.jsonl
# Found query file: dev_official/QuestionFields.jsonl
# Found query file: train_fusion/QuestionFields.jsonl
# JAVA_OPTS=-Xms4070758k -Xmx28495306k -server
# [main] INFO edu.cmu.lti.oaqa.flexneuart.apps.BuildFwdIndexApp - Processing field: 'text_unlemm'
# [main] INFO edu.cmu.lti.oaqa.flexneuart.apps.BuildFwdIndexApp - Forward index type: dataDict
# [main] INFO edu.cmu.lti.oaqa.flexneuart.apps.BuildFwdIndexApp - Forward index storage type: mapdb
# [main] INFO edu.cmu.lti.oaqa.flexneuart.apps.BuildFwdIndexApp - Forward index field type: parsedText
# [main] INFO edu.cmu.lti.oaqa.flexneuart.fwdindx.MapDbBackend - MapDB opened for writing: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/forward_index/text_unlemm.mapdb_dataDict using expected # of entries: 1000000000
# [main] INFO edu.cmu.lti.oaqa.flexneuart.fwdindx.MapDbBackend - # of segments/block size/# of levels 30/32/5
# [main] INFO edu.cmu.lti.oaqa.flexneuart.fwdindx.ForwardIndex - Creating a new forward index, maximum # of docs to process: 2147483647
# [main] INFO edu.cmu.lti.oaqa.flexneuart.fwdindx.ForwardIndex - Processed 100000 documents
# [main] WARN edu.cmu.lti.oaqa.flexneuart.fwdindx.ForwardIndex - Warning: empty field 'text_unlemm' for document '1918840'
# [main] INFO edu.cmu.lti.oaqa.flexneuart.fwdindx.ForwardIndex - Processed 200000 documents
# [main] INFO edu.cmu.lti.oaqa.flexneuart.fwdindx.ForwardIndex - Processed 300000 documents
# [main] WARN edu.cmu.lti.oaqa.flexneuart.fwdindx.ForwardIndex - Warning: empty field 'text_unlemm' for document '8025660'
# [main] INFO edu.cmu.lti.oaqa.flexneuart.fwdindx.ForwardIndex - Processed 400000 documents
# [main] INFO edu.cmu.lti.oaqa.flexneuart.fwdindx.ForwardIndex - Processed 500000 documents
# [main] WARN edu.cmu.lti.oaqa.flexneuart.fwdindx.ForwardIndex - Warning: empty field 'text_unlemm' for document '14453381'
# [main] INFO edu.cmu.lti.oaqa.flexneuart.fwdindx.ForwardIndex - Processed 600000 documents
# [main] INFO edu.cmu.lti.oaqa.flexneuart.fwdindx.ForwardIndex - Processed 700000 documents
# [main] WARN edu.cmu.lti.oaqa.flexneuart.fwdindx.ForwardIndex - Warning: empty field 'text_unlemm' for document '19526113'
# [main] INFO edu.cmu.lti.oaqa.flexneuart.fwdindx.ForwardIndex - Finished processing file: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/input_data/pass_sample/AnswerFields.jsonl.gz
# [main] INFO edu.cmu.lti.oaqa.flexneuart.fwdindx.ForwardIndex - Final statistics:
# [main] INFO edu.cmu.lti.oaqa.flexneuart.fwdindx.ForwardIndex - Number of documents 774392, total number of words 43843253, average reduction due to keeping only unique words 1,242173
# Using collection root: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections
# ==========================================================================
# Input data directory:      /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/input_data
# Forward index directory:   /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/forward_index
# Remove old index?:         0
# Field definition:          title:parsedBOW
# Index type arguments:
# ==========================================================================
# Checking input sub-directory: bitext
# Checking input sub-directory: dev
# Checking input sub-directory: dev_official
# Checking input sub-directory: pass_sample
# Found indexable data file: pass_sample/AnswerFields.jsonl.gz
# Checking input sub-directory: train_fusion
# Found query file: bitext/QuestionFields.jsonl
# Found query file: dev/QuestionFields.jsonl
# Found query file: dev_official/QuestionFields.jsonl
# Found query file: train_fusion/QuestionFields.jsonl
# JAVA_OPTS=-Xms4070758k -Xmx28495306k -server
# [main] INFO edu.cmu.lti.oaqa.flexneuart.apps.BuildFwdIndexApp - Processing field: 'title'
# [main] INFO edu.cmu.lti.oaqa.flexneuart.apps.BuildFwdIndexApp - Forward index type: dataDict
# [main] INFO edu.cmu.lti.oaqa.flexneuart.apps.BuildFwdIndexApp - Forward index storage type: mapdb
# [main] INFO edu.cmu.lti.oaqa.flexneuart.apps.BuildFwdIndexApp - Forward index field type: parsedBOW
# [main] INFO edu.cmu.lti.oaqa.flexneuart.fwdindx.MapDbBackend - MapDB opened for writing: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/forward_index/title.mapdb_dataDict using expected # of entries: 1000000000
# [main] INFO edu.cmu.lti.oaqa.flexneuart.fwdindx.MapDbBackend - # of segments/block size/# of levels 30/32/5
# [main] INFO edu.cmu.lti.oaqa.flexneuart.fwdindx.ForwardIndex - Creating a new forward index, maximum # of docs to process: 2147483647
# java.lang.Exception: Warning: now field 'title' for document '2'
# 	at edu.cmu.lti.oaqa.flexneuart.fwdindx.ForwardIndex.createIndex(ForwardIndex.java:851)
# 	at edu.cmu.lti.oaqa.flexneuart.apps.BuildFwdIndexApp.createForwardIndex(BuildFwdIndexApp.java:193)
# 	at edu.cmu.lti.oaqa.flexneuart.apps.BuildFwdIndexApp.main(BuildFwdIndexApp.java:158)
# [main] ERROR edu.cmu.lti.oaqa.flexneuart.apps.BuildFwdIndexApp - Terminating due to an exception: java.lang.Exception: Warning: now field 'title' for document '2'
# Using collection root: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections
# ==========================================================================
# Input data directory:      /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/input_data
# Forward index directory:   /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/forward_index
# Remove old index?:         0
# Field definition:          text_bert_tok:parsedText
# Index type arguments:
# ==========================================================================
# Checking input sub-directory: bitext
# Checking input sub-directory: dev
# Checking input sub-directory: dev_official
# Checking input sub-directory: pass_sample
# Found indexable data file: pass_sample/AnswerFields.jsonl.gz
# Checking input sub-directory: train_fusion
# Found query file: bitext/QuestionFields.jsonl
# Found query file: dev/QuestionFields.jsonl
# Found query file: dev_official/QuestionFields.jsonl
# Found query file: train_fusion/QuestionFields.jsonl
# JAVA_OPTS=-Xms4070758k -Xmx28495306k -server
# [main] INFO edu.cmu.lti.oaqa.flexneuart.apps.BuildFwdIndexApp - Processing field: 'text_bert_tok'
# [main] INFO edu.cmu.lti.oaqa.flexneuart.apps.BuildFwdIndexApp - Forward index type: dataDict
# [main] INFO edu.cmu.lti.oaqa.flexneuart.apps.BuildFwdIndexApp - Forward index storage type: mapdb
# [main] INFO edu.cmu.lti.oaqa.flexneuart.apps.BuildFwdIndexApp - Forward index field type: parsedText
# [main] INFO edu.cmu.lti.oaqa.flexneuart.fwdindx.MapDbBackend - MapDB opened for writing: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/forward_index/text_bert_tok.mapdb_dataDict using expected # of entries: 1000000000
# [main] INFO edu.cmu.lti.oaqa.flexneuart.fwdindx.MapDbBackend - # of segments/block size/# of levels 30/32/5
# [main] INFO edu.cmu.lti.oaqa.flexneuart.fwdindx.ForwardIndex - Creating a new forward index, maximum # of docs to process: 2147483647
# [main] INFO edu.cmu.lti.oaqa.flexneuart.fwdindx.ForwardIndex - Processed 100000 documents
# [main] INFO edu.cmu.lti.oaqa.flexneuart.fwdindx.ForwardIndex - Processed 200000 documents
# [main] INFO edu.cmu.lti.oaqa.flexneuart.fwdindx.ForwardIndex - Processed 300000 documents
# [main] INFO edu.cmu.lti.oaqa.flexneuart.fwdindx.ForwardIndex - Processed 400000 documents
# [main] INFO edu.cmu.lti.oaqa.flexneuart.fwdindx.ForwardIndex - Processed 500000 documents
# [main] INFO edu.cmu.lti.oaqa.flexneuart.fwdindx.ForwardIndex - Processed 600000 documents
# [main] INFO edu.cmu.lti.oaqa.flexneuart.fwdindx.ForwardIndex - Processed 700000 documents
# [main] INFO edu.cmu.lti.oaqa.flexneuart.fwdindx.ForwardIndex - Finished processing file: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/input_data/pass_sample/AnswerFields.jsonl.gz
# [main] INFO edu.cmu.lti.oaqa.flexneuart.fwdindx.ForwardIndex - Final statistics:
# [main] INFO edu.cmu.lti.oaqa.flexneuart.fwdindx.ForwardIndex - Number of documents 774392, total number of words 108942024, average reduction due to keeping only unique words 1,687564
# Using collection root: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections
# ==========================================================================
# Input data directory:      /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/input_data
# Forward index directory:   /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/forward_index
# Remove old index?:         0
# Field definition:          text_raw:textRaw
# Index type arguments:
# ==========================================================================
# Checking input sub-directory: bitext
# Checking input sub-directory: dev
# Checking input sub-directory: dev_official
# Checking input sub-directory: pass_sample
# Found indexable data file: pass_sample/AnswerFields.jsonl.gz
# Checking input sub-directory: train_fusion
# Found query file: bitext/QuestionFields.jsonl
# Found query file: dev/QuestionFields.jsonl
# Found query file: dev_official/QuestionFields.jsonl
# Found query file: train_fusion/QuestionFields.jsonl
# JAVA_OPTS=-Xms4070758k -Xmx28495306k -server
# [main] INFO edu.cmu.lti.oaqa.flexneuart.apps.BuildFwdIndexApp - Processing field: 'text_raw'
# [main] INFO edu.cmu.lti.oaqa.flexneuart.apps.BuildFwdIndexApp - Forward index type: dataDict
# [main] INFO edu.cmu.lti.oaqa.flexneuart.apps.BuildFwdIndexApp - Forward index storage type: mapdb
# [main] INFO edu.cmu.lti.oaqa.flexneuart.apps.BuildFwdIndexApp - Forward index field type: textRaw
# [main] INFO edu.cmu.lti.oaqa.flexneuart.fwdindx.MapDbBackend - MapDB opened for writing: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/forward_index/text_raw.mapdb_dataDict using expected # of entries: 1000000000
# [main] INFO edu.cmu.lti.oaqa.flexneuart.fwdindx.MapDbBackend - # of segments/block size/# of levels 30/32/5
# [main] INFO edu.cmu.lti.oaqa.flexneuart.fwdindx.ForwardIndex - Creating a new forward index, maximum # of docs to process: 2147483647
# [main] INFO edu.cmu.lti.oaqa.flexneuart.fwdindx.ForwardIndex - Processed 100000 documents
# [main] INFO edu.cmu.lti.oaqa.flexneuart.fwdindx.ForwardIndex - Processed 200000 documents
# [main] INFO edu.cmu.lti.oaqa.flexneuart.fwdindx.ForwardIndex - Processed 300000 documents
# [main] INFO edu.cmu.lti.oaqa.flexneuart.fwdindx.ForwardIndex - Processed 400000 documents
# [main] INFO edu.cmu.lti.oaqa.flexneuart.fwdindx.ForwardIndex - Processed 500000 documents
# [main] INFO edu.cmu.lti.oaqa.flexneuart.fwdindx.ForwardIndex - Processed 600000 documents
# [main] INFO edu.cmu.lti.oaqa.flexneuart.fwdindx.ForwardIndex - Processed 700000 documents
# [main] INFO edu.cmu.lti.oaqa.flexneuart.fwdindx.ForwardIndex - Finished processing file: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/input_data/pass_sample/AnswerFields.jsonl.gz
# [main] INFO edu.cmu.lti.oaqa.flexneuart.fwdindx.ForwardIndex - Final statistics:
# [main] INFO edu.cmu.lti.oaqa.flexneuart.fwdindx.ForwardIndex - Number of documents 774392, total number of words 0, average reduction due to keeping only unique words 0,000000
