# %% [markdown]
# # Training IBM Model 1 (non-neural lexical translation model)

# %% [markdown]
# ### Two things to do before we start:
# 1. Point environment variable `COLLECT_ROOT` to the collection root.
# 2. Change directory to the location of installed scripts/binaries

# %%
import os
COLLECT_ROOT = os.path.abspath("collections")
os.makedirs(COLLECT_ROOT, exist_ok=True)
# %env COLLECT_ROOT={COLLECT_ROOT}
print(COLLECT_ROOT)
# Out:
# env: COLLECT_ROOT=/tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections
# /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections

# %%
# %cd ./flexneuart_scripts/
# Out:
# /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/flexneuart_scripts

# %% [markdown]
# Training an IBM Model 1 model
# Here we create a model for the field text_bert_tok. This script requires MGIZA to be compiled (make sure you ran the script install_packages.sh):

# %%
# !./giza/create_tran.sh wikipedia_dpr_nq_sample text_bert_tok
# Out:
# Using collection root: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections
# ...
# GIZA (output) sub-directory:  giza
# Bitext sub-directory:         bitext
# Source dir prefix:            /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/derived_data/bitext
# Target dir prefix:            /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/derived_data/giza
# Sample probability:           1
# ...
# Creating:
# Dir=/tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/derived_data/giza/text_bert_tok.orig
# Creating: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/derived_data/giza/text_bert_tok.orig
# /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/flexneuart_scripts
# ...

# %% [markdown]
# Sanity check, inspect training perplexity:

# %%
# !cat $COLLECT_ROOT/wikipedia_dpr_nq_sample/derived_data/giza/text_bert_tok.orig/output.perp
# Out:
# #trnsz	tstsz	iter	model	trn-pp		test-pp		trn-vit-pp		tst-vit-pp
# 1190942	0	0	Model1	88197.8		N/A		inf		N/A
# 1190942	0	1	Model1	932.098		N/A		4438.64		N/A
# 1190942	0	2	Model1	651.752		N/A		2432.73		N/A
# 1190942	0	3	Model1	582.679		N/A		1863.23		N/A
# 1190942	0	4	Model1	556.998		N/A		1619.48		N/A

# %% [markdown]
# It further needs to be pruned and converted to a binary format (infrequent tokens need to be filtered out as well).
# Note that for BERT-tokenized text, which has less than
# 100K unique tokens, the __specified__ maximum number of most frequent words
# is too high. However, it makes sense for, e.g.,
# unlemmatized text fields with large vocabularies.

# %%
# !min_tran_prob=0.001; top_word_qty=100000; echo $min_tran_prob; ./giza/filter_tran_table_and_voc.sh wikipedia_dpr_nq_sample text_bert_tok $min_tran_prob $top_word_qty
# Out:
# 0.001
# Using collection root: /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections
# ...
#  This script uses (but doesn't modify), e.g. the data created by ./giza/create_tran.sh which is placed in directory:
# /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/derived_data/giza/text_bert_tok.orig
# The filtered output is stored in the following directory:
# /tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/derived_data/giza/text_bert_tok
# ...
# Filtering vocabularies : '/tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/derived_data/giza/text_bert_tok.orig' -> '/tempory/the_three_potatoes/ri_project/workspaces/amelie/FlexNeuART-IR-TTP/demo/collections/wikipedia_dpr_nq_sample/derived_data/giza/text_bert_tok'
# ...
